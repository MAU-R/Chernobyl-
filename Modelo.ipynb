# %%
import pandas as  pd
import numpy 

datos = pd.read_excel("Datos1.xlsx")
datos
# Out:
#             Marca temporal membresia                 Sueldo  \
# 0  2022-11-22 18:36:30.384        No                  50000
# 1  2022-11-22 18:36:37.764        Si                  36000
# 2  2022-11-22 18:37:03.041        Si                  30000
# 3  2022-11-22 18:46:10.578        Si                  60000
# 4  2022-11-22 18:49:29.634        Si                  25000
# 5  2022-11-22 18:51:27.370        Si    No genero ingresos
# 6  2022-11-22 18:52:14.421        Si                  20000
# 7  2022-11-22 18:59:19.719        Si                  20000
# 8  2022-11-22 19:00:05.715        Si                   7000
# 9  2022-11-22 19:01:03.870        Si                  80000
# 10 2022-11-22 19:02:04.387        Si                  30000
# 11 2022-11-22 19:03:52.790        Si                  45000
# 12 2022-11-22 19:15:04.628        Si  Aproximadamente 30000
# 13 2022-11-22 19:30:11.517        Si                   3000
# 14 2022-11-22 19:35:13.694        Si                  24000
# ...

# %%
datos['gastos'] = datos['gastos'].replace(100,datos['gastos'].mean()) 
datos
# Out:
#             Marca temporal membresia                 Sueldo  \
# 0  2022-11-22 18:36:30.384        No                  50000
# 1  2022-11-22 18:36:37.764        Si                  36000
# 2  2022-11-22 18:37:03.041        Si                  30000
# 3  2022-11-22 18:46:10.578        Si                  60000
# 4  2022-11-22 18:49:29.634        Si                  25000
# 5  2022-11-22 18:51:27.370        Si    No genero ingresos
# 6  2022-11-22 18:52:14.421        Si                  20000
# 7  2022-11-22 18:59:19.719        Si                  20000
# 8  2022-11-22 19:00:05.715        Si                   7000
# 9  2022-11-22 19:01:03.870        Si                  80000
# 10 2022-11-22 19:02:04.387        Si                  30000
# 11 2022-11-22 19:03:52.790        Si                  45000
# 12 2022-11-22 19:15:04.628        Si  Aproximadamente 30000
# 13 2022-11-22 19:30:11.517        Si                   3000
# 14 2022-11-22 19:35:13.694        Si                  24000
# ...
