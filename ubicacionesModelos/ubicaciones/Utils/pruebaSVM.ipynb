# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# scikit learn
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

# %%
datos = pd.read_excel("../database/datitos.xlsx");
x=datos
x['Latitud']
import random
for i in range(138):
    x['Latitud'][i]=(x['Latitud'][i]-random.uniform(0.01000, 0.00010))
    x['Longitud'][i]=(x['Longitud'][i]-random.uniform(0.01000, 0.00010))

y= x['clase'].values
datos= []
l=x.shape[0]-1
for j in range((x.shape[0])):
    datos.append([x['Sueldo'][j],x['membresiasStreaming'][j],x['plataforma'][j], x['gastos'][j]])
datos
# Out:
# C:\Users\mau20\AppData\Local\Temp\ipykernel_14124\259733727.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Latitud'][i]=(x['Latitud'][i]-random.uniform(0.01000, 0.00010))
# C:\Users\mau20\AppData\Local\Temp\ipykernel_14124\259733727.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Longitud'][i]=(x['Longitud'][i]-random.uniform(0.01000, 0.00010))
# [[50000, 1, 1, 500],
#  [36000, 2, 1, 200],
#  [30000, 2, 2, 300],
#  [60000, 3, 3, 500],
#  [25000, 3, 4, 470],
#  [0, 1, 1, 250],
#  [20000, 2, 1, 300],
#  [20000, 3, 2, 1000],
#  [7000, 4, 4, 139],
#  [80000, 3, 4, 1000],
#  [30000, 3, 2, 300],
# ...

# %%
x_train, x_test, y_train, y_test =train_test_split(datos, y, test_size=0.3, random_state=0, stratify=y)

# %%
sc = StandardScaler()
sc.fit(x_train)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)
x_train_std
# Out:
# array([[-0.33064854, -0.15025941, -0.89827492, -0.18991042],
#        [-0.39950225,  1.11714608,  0.09752699, -0.12545772],
#        [-0.20300151,  1.11714608,  0.09752699, -0.1169451 ],
#        [ 0.89247398,  0.48344333,  0.09752699,  1.73272575],
#        [ 1.35319084,  0.48344333,  0.59542794,  2.22524166],
#        [ 2.14565462,  1.75084883,  2.0891308 ,  0.62486898],
#        [-1.12203551, -0.78396216, -1.39617587, -1.09468039],
#        [-1.14237166, -1.41766491,  0.09752699, -0.87213616],
#        [-0.84618994, -1.41766491, -0.89827492, -0.96091064],
#        [ 2.4693409 , -0.15025941,  0.59542794,  1.84703809],
#        [-0.91375149, -0.78396216,  1.0933289 , -1.10319301],
#        [ 0.31389359, -0.78396216,  0.09752699,  1.69989136],
#        [-0.06443264,  0.48344333, -0.40037396, -0.39542941],
#        [-1.00226451, -0.78396216, -1.39617587, -1.08859994],
#        [ 0.88908975,  0.48344333,  1.59122985,  0.23450452],
# ...

# %%
svc = SVC(C=1.0, random_state=1, kernel='linear')
 
# Entrenar modelo
svc.fit(x_train_std, y_train)
# Out:
# 42

# %%
y_predict = svc.predict(x_train_std)
 
# Calcular rendimiento
 
# print("Porcentaje de clasificación %.3f" %metrics.accuracy_score(y_test, y_predict))
print("Porcentaje de clasificación %.3f" %metrics.accuracy_score(y_train, y_predict))
#salida de svm

for i in range(len(y_predict)):
  if (y_train[i]!= y_predict[i]):
    print(f"Individuo {i} E {y_train[i]} C {y_predict[i]}")
# Out:
# Porcentaje de clasificación 0.938
# Individuo 17 E 2 C 1
# Individuo 46 E 2 C 1
# Individuo 49 E 2 C 1
# Individuo 66 E 2 C 1
# Individuo 81 E 3 C 2
# Individuo 90 E 2 C 1

# %%
len(y_predict)
# Out:
# 97
